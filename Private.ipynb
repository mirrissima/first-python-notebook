# %%
import pandas as pd

# %%
ubstest = pd.read_csv("export-4.csv")

# %%
ubstest.head(30)
# Out:
#    Bewertungsdatum;Bankbeziehung;Portfolio;Produkt;IBAN;Whrg.;Datum von;Datum bis;Beschreibung;Abschlussdatum;Buchungsdatum;Valuta;Beschreibung 1;Beschreibung 2;Beschreibung 3;Transaktions-Nr.;Devisenkurs zum Originalbetrag in Abrechnungsw�hrung;Einzelbetrag;Belastung;Gutschrift;Saldo  \
# 0   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 1   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 2   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 3   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 4   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 5   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 6   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 7   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 8   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 9   27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 10  27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# 11  27.06.2017;0230 00306913;;0230 00306913.40M;CH...
# ...

# %%
ubstest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
# Bewertungsdatum;Bankbeziehung;Portfolio;Produkt;IBAN;Whrg.;Datum von;Datum bis;Beschreibung;Abschlussdatum;Buchungsdatum;Valuta;Beschreibung 1;Beschreibung 2;Beschreibung 3;Transaktions-Nr.;Devisenkurs zum Originalbetrag in Abrechnungsw�hrung;Einzelbetrag;Belastung;Gutschrift;Saldo    29 non-null object
# Unnamed: 1                                                                                                                                                                                                                                                                                    13 non-null object
# ...
